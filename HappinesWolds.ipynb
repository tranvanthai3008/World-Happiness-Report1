# %%
# Загрузить необходимые пакеты для работы
# !pip install geopandas
# !pip install pandas 
# !pip install jupyter_bokeh
# Out:
# Requirement already satisfied: geopandas in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (0.6.2)
# Requirement already satisfied: fiona in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from geopandas) (1.8.21)
# Requirement already satisfied: pandas>=0.23.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from geopandas) (1.4.2)
# Requirement already satisfied: shapely in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from geopandas) (1.8.1.post1)
# Requirement already satisfied: pyproj in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from geopandas) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23.0->geopandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23.0->geopandas) (1.22.3+vanilla)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from pandas>=0.23.0->geopandas) (2021.3)
# Requirement already satisfied: munch in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: setuptools in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from fiona->geopandas) (57.4.0)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: gdal~=3.4.1 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from fiona->geopandas) (3.4.2)
# Requirement already satisfied: attrs>=17 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from fiona->geopandas) (21.4.0)
# Requirement already satisfied: cligj>=0.5 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from fiona->geopandas) (0.7.2)
# Requirement already satisfied: six>=1.7 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from fiona->geopandas) (1.16.0)
# Requirement already satisfied: click>=4.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from fiona->geopandas) (8.0.4)
# Requirement already satisfied: certifi in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from fiona->geopandas) (2021.10.8)
# Requirement already satisfied: colorama in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from click>=4.0->fiona->geopandas) (0.4.4)
# Requirement already satisfied: pandas in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from pandas) (1.22.3+vanilla)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: jupyter_bokeh in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (3.0.4)
# Requirement already satisfied: ipywidgets>=7.6.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from jupyter_bokeh) (7.7.0)
# Requirement already satisfied: bokeh>=2.4.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from jupyter_bokeh) (2.4.2)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from bokeh>=2.4.0->jupyter_bokeh) (3.1.2)
# Requirement already satisfied: numpy>=1.11.3 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from bokeh>=2.4.0->jupyter_bokeh) (1.22.3+vanilla)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from bokeh>=2.4.0->jupyter_bokeh) (4.0.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from bokeh>=2.4.0->jupyter_bokeh) (6.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from bokeh>=2.4.0->jupyter_bokeh) (9.0.1)
# Requirement already satisfied: packaging>=16.8 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from bokeh>=2.4.0->jupyter_bokeh) (21.3)
# Requirement already satisfied: tornado>=5.1 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from bokeh>=2.4.0->jupyter_bokeh) (6.1)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.6.0->jupyter_bokeh) (5.1.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.6.0->jupyter_bokeh) (1.1.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.6.0->jupyter_bokeh) (6.13.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.6.0->jupyter_bokeh) (8.3.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.6.0->jupyter_bokeh) (5.3.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.6.0->jupyter_bokeh) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipywidgets>=7.6.0->jupyter_bokeh) (3.6.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->jupyter_bokeh) (0.1.3)
# Requirement already satisfied: nest-asyncio in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->jupyter_bokeh) (1.5.5)
# Requirement already satisfied: psutil in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->jupyter_bokeh) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->jupyter_bokeh) (1.6.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.0->jupyter_bokeh) (7.3.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (2.12.0)
# Requirement already satisfied: colorama in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.4.4)
# Requirement already satisfied: decorator in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (3.0.29)
# Requirement already satisfied: backcall in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (57.4.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from Jinja2>=2.9->bokeh>=2.4.0->jupyter_bokeh) (2.1.1)
# Requirement already satisfied: jupyter-core in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.0->jupyter_bokeh) (4.10.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.0->jupyter_bokeh) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.0->jupyter_bokeh) (2.15.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from packaging>=16.8->bokeh>=2.4.0->jupyter_bokeh) (3.0.7)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (6.4.11)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.6.0->jupyter_bokeh) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.18.1)
# Requirement already satisfied: pyzmq>=22.3 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.0->jupyter_bokeh) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.0->jupyter_bokeh) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.0->jupyter_bokeh) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.6.0->jupyter_bokeh) (304)
# Requirement already satisfied: nbconvert>=5 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (6.5.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (21.3.0)
# Requirement already satisfied: prometheus-client in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.14.1)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.13.3)
# Requirement already satisfied: wcwidth in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.2.5)
# Requirement already satisfied: pure-eval in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.2.2)
# Requirement already satisfied: executing in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.6.0->jupyter_bokeh) (2.0.5)
# Requirement already satisfied: defusedxml in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (1.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.6.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.2.2)
# Requirement already satisfied: bleach in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (5.0.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (4.11.1)
# Requirement already satisfied: six>=1.5 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.0->jupyter_bokeh) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (2.0.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\tran van thai\appdata\local\programs\python\python39\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.0->jupyter_bokeh) (2.21)

# %%
# Импорт библиотеки для работы
import geopandas as gpd 
import pandas as pd 
import json 
import glob 
import os 
import numpy as np
import requests
from ipywidgets import interact 
from bokeh.resources import INLINE 
from bokeh.io import output_notebook, show, push_notebook
from bokeh.plotting import figure 
from bokeh.models import GeoJSONDataSource, LinearColorMapper, ColorBar 
from bokeh.palettes import brewer,mpl
from bokeh.io import curdoc, output_notebook 
from bokeh.models import Slider, HoverTool,CustomJS 
from bokeh.layouts import widgetbox, row, column
from bokeh.application import Application
from bokeh.application.handlers import FunctionHandler
#output_notebook()

# %%
# Создание класса карты со следующими свойствами:
# Заголовок -title
# Патлетт -palette
# Линейный цветовой картограф -color_mapper
# всплывающие подсказки -hover
# фигура -fig
class Map:
    # Метод конструктора
    def __init__(self):
        self.title="To do some thing title for map"
        self.palette=mpl['Plasma'][10]
        self.color_mapper=LinearColorMapper(palette = self.palette, low = 0, high = 10)
        self.hover=HoverTool(tooltips = [ ('Country','@country'),('Score', '@Score')])
        self.color_bar=ColorBar(color_mapper=self.color_mapper, label_standoff=8,width = 500, height = 20, border_line_color=None,location = (0,0), orientation = 'horizontal')
        self.fig=figure(title = self.title, plot_height = 600 , plot_width = 950, toolbar_location = None, tools = [self.hover])
    # Метод  установки значения для патлетта
    def setPalette(self,palette):
        self.palette=palette
    # Метод  установки значения для заголовок
    def setTitle(self,title):
        self.title=title
    # Метод  установки значения для линейного цветовгого картографа
    def setColorMapper(self, palette, low, high):
         self.color_mapper=LinearColorMapper(palette = self.palette, low = low, high = high)
    # Метод  установки значения для всплывающих подсказок
    def setHover(self,label, value):
        self.hover=HoverTool(tooltips=(label, value))
    # Метод  установки значения для цветной полосы
    def setColorBar(self,color_mapper,label_standoff, w, h, color, point, orientation):
        self.color_bar=ColorBar(color_mapper=color_mapper, label_standoff=label_standoff,width = w, height = h, border_line_color=color,location = point, orientation = orientation)
    # Метод  установки значения для фигуры
    def setFigure(self,title,ph,pw,toolbar,hover):
        self.fig=figure(title = title, plot_height = ph , plot_width = pw, toolbar_location = None, tools = [hover])

# Создание класса worldHappines наследования свойства с класса Map
class worldHappines(Map):
    # Предобработка данных
    def processingData(self):
        shapefile = '110m_cultural/ne_110m_admin_0_countries.shp'
        gdf = gpd.read_file(shapefile)[['ADMIN', 'ADM0_A3', 'geometry']]
        gdf.columns = ['country', 'country_code', 'geometry']
        listData_1 = ['2019.csv', '2018.csv']
        listData_2 = ['2015.csv', '2016.csv']
        df1 = pd.concat((pd.read_csv(f).assign(Year=os.path.basename(f[0:4])) for f in listData_1), sort=False)
        df2 = pd.concat((pd.read_csv(f).assign(Year=os.path.basename(f[0:4])) for f in listData_2), sort=False)
        df3 = pd.read_csv('2017.csv').assign(Year="2017")
        df1['Country'] = df1['Country or region']
        df2['Score'] = df2['Happiness Score']
        df3['Score'] = df3['Happiness.Score']
        countries = pd.concat([df1[['Country', 'Score', 'Year']], df2[['Country', 'Score', 'Year']], df3[['Country', 'Score', 'Year']]], sort=False)
        countries = countries.replace('United States', 'United States of America')
        return gdf,countries
    # Метод конструктора без параметров
    def __init__(self):
        gdf,countries=self.processingData();
        self.gdf=gdf
        self.countries=countries
        # вызывает конструктора класса отца
        Map.__init__(self)
    # Получение данные в формате 
    def json_data(self,selectedYear,gdf,countries):
        year = selectedYear
        df_yr = countries[countries['Year'] == year]
        merged = gdf.merge(df_yr, left_on ='country', right_on ='Country', how ='left')
        merged['Score'] = merged.Score.fillna("N/A")
        merged_json = json.loads(merged.to_json())
        json_data = json.dumps(merged_json)
        return json_data
    # Полимозфизма метода setFigure из отца класса
    def setFigure(self,xgrid,ygrid,fontText,src,fillColor,lineColor,lineWitdh,alpha,colorbar,valueColorbar):
        self.fig.xgrid.grid_line_color = xgrid
        self.fig.ygrid.grid_line_color = ygrid
        self.fig.title.text_font_size = fontText
        self.fig.patches('xs','ys', source = src,fill_color = fillColor, line_color = lineColor, line_width = lineWitdh, fill_alpha = alpha)
        self.fig.add_layout(colorbar, valueColorbar)
    # Рисование карты по году
    def draw_map(self,year):
        self.title='Happiness Score by Country  '+ str(year)
        self.jsondata=self.json_data(str(year),self.gdf,self.countries)
        self.geosource = GeoJSONDataSource(geojson = self.jsondata)
        super().setFigure(self.title,600,950,None,self.hover)
        self.setFigure(None,None,'12pt',self.geosource,{'field' :'Score', 'transform' : self.color_mapper},'white',0.5,1,self.color_bar,'below')
        layout = column(self.fig,widgetbox())
        curdoc().add_root(layout)
        output_notebook(INLINE)
        show(layout,notebook_handle=True)

# %%
# Вызывает класс worldHappines
wh=worldHappines()
# Интеракт для выбрана года, отображающего уровня счастья стран в исходном. 
interact(wh.draw_map,year=['2015','2016','2017','2018','2019'])
# Out:
# C:\Users\Tran Van Thai\AppData\Local\Programs\Python\Python39\lib\site-packages\geopandas\array.py:85: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out
# interactive(children=(Dropdown(description='year', options=('2015', '2016', '2017', '2018', '2019'), value='20…
# <function ipywidgets.widgets.interaction._InteractFactory.__call__.<locals>.<lambda>(*args, **kwargs)>
